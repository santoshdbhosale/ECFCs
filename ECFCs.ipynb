# %%
import pandas as pd
from clustergrammer_widget import *
net = Network(clustergrammer_widget)

# %%
pip install --upgrade clustergrammer
# Out:
# Requirement already satisfied: clustergrammer in c:\users\santoshb\anaconda3\lib\site-packages (1.13.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\santoshb\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\santoshb\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\santoshb\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\santoshb\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\santoshb\anaconda3\lib\site-packages)

# %%
from clustergrammer2 import net
# Out:
# >> clustergrammer2 backend version 0.17.0

# %%
# load our data
net.load_file('ECFCs_Sig.tsv')

# %%
# check shape of data
net.dat['mat'].shape
# Out:
# (590, 32)

# %%
net.cluster(views=[])
net.widget()
# Out:
# CGM2(network='{"row_nodes": [{"name": "Gene: DENND6A", "ini": 590, "clust": 570, "rank": 541, "rankvar": 52, "…
